# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
monthly_sales = pd.read_csv("monthly_sales_cleaned.csv")
forecast = pd.read_csv("sales_forecast.csv")

monthly_sales.head(), forecast.head()
# Out:
# (        Month      Sales
#  0  2014-01-01  14236.895
#  1  2014-02-01   4519.892
#  2  2014-03-01  55691.009
#  3  2014-04-01  28295.345
#  4  2014-05-01  23648.287,
#             ds          yhat    yhat_lower    yhat_upper
#  0  2014-01-01  16956.114468   7913.008587  25862.571262
#  1  2014-02-01   3734.545826  -5164.972618  11952.717731
#  2  2014-03-01  42557.622343  34030.991875  50863.071310
#  3  2014-04-01  26439.241492  18176.848393  35128.887735
#  4  2014-05-01  26642.889288  17954.276626  35479.635302)

# %%
plt.figure(figsize=(10,5))
plt.plot(monthly_sales['Month'], monthly_sales['Sales'])
plt.title("Monthly Sales Trend")
plt.xlabel("Month")
plt.ylabel("Sales")
plt.show()
